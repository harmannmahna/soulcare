# %% [markdown]
# # SoulCare — Qwen2.5-0.5B LoRA (risk labels)
#
# Runtime → Change runtime type → GPU (T4).
#
# No paid API key. Optional free Hugging Face token if the Qwen download is gated. Full steps: `docs/qwen-lora.md`.

# %%
# !pip -q install "transformers>=4.44" datasets peft accelerate bitsandbytes pandas scikit-learn

# %%
# !git clone https://github.com/harmannmahna/soulcare.git
# %cd soulcare/backend

# %%
import os
os.environ["HF_TOKEN"] = ""  # paste hf_... only if from_pretrained asks to log in

# %%
# !python ml/train_qwen_lora.py

# %% [markdown]
# Download `ml/artifacts/lora_adapter/` into the repo. Set `RISK_MODEL_PATH` to that folder.
#
# If Qwen OOMs, run `python ml/train_distilbert_lora.py` instead (same export path).
